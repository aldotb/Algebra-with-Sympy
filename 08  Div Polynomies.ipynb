# %% [markdown]
# ![image.png](attachment:73517cb3-98da-4c40-8d77-21db4972fcb9.png)

# %% [markdown]
# #### Library :  Libaldo.py
# * This library include:
#   * sympy.py The best symbolic math library for me
#   * numpy as np, matplotlib.pyplot as plt IPython.display
#   * libaldo_math2.py this module have some util tools for classic math functions
#   * libaldo_algorith.py some algorith to manage simple math functions
#   * lib_MyEq , this module manage maths Eq
#   * lib_MyEqEq , this module will be MyEq=MyEq
# * Also include the most used variables like   ,x,y,z,alpha,mu..   etc... mayby 150 variables

# %% [markdown]
# ![image.png](attachment:54df9e1e-714e-4371-a5f2-ffb26663218e.png)

# %% [markdown]
# ![image.png](attachment:73517cb3-98da-4c40-8d77-21db4972fcb9.png)

# %% [markdown]
# ![image.png](attachment:c57d27b3-20b4-4d53-ab1f-be68e4e10533.png)

# %%
# This scrip initializes all variables. 
import sys
sys.path.insert(0, './Libaldo')
from Libaldo import *

# %%
P=MyEq(x**8+a*x**4+b,'P')
d=MyEq(x*x+x+1,'d')
# Out:
# $\displaystyle P =a x^{4} + b + x^{8}$
# $\displaystyle d =x^{2} + x + 1$

# %%
R=P.rem(d,'R')
# Out:
# $\displaystyle R =a x + b - x - 1$

# %%
b=R.solveset(b,x=0)
# Out:
# $\displaystyle b =1$
# $\displaystyle R =a x - x$

# %%
a=R.solve(a)
# Out:
# $\displaystyle a =1$

# %% [markdown]
# ![image.png](attachment:73517cb3-98da-4c40-8d77-21db4972fcb9.png)

# %% [markdown]
# ![image.png](attachment:d6503bb3-2cfe-4a77-a2ae-38f1ca228fda.png)

# %%
# This scrip initializes all variables. 
import sys
sys.path.insert(0, './Libaldo')
from Libaldo import *

# %%
P=MyEq(2*x**5+3*x**4+b*x**3+6*b*x*x+x+a,'P')
d=MyEq(x*x-x+b,'d')
R=MyEq(2*x+3,'R')
# Out:
# $\displaystyle P =a + b x^{3} + 6 b x^{2} + 2 x^{5} + 3 x^{4} + x$
# $\displaystyle d =b + x^{2} - x$
# $\displaystyle R =2 x + 3$

# %%
R1=P.rem(d,'R1')
# Out:
# $\displaystyle R1 =a + b^{2} x - 5 b x - 5 b + 6 x$

# %%
A=MQ(R,R1)
# Out:
# $\displaystyle 2 x + 3 = a + b^{2} x - 5 b x - 5 b + 6 x$

# %%
A.factorize(x)
# Out:
# $\displaystyle 2 x + 3 = a - 5 b + x \left(b^{2} - 5 b + 6\right)$

# %%
e1=MQ(a-5*b,3)
e2=MQ(2,b*b-5*b+6)
# Out:
# $\displaystyle a - 5 b = 3$
# $\displaystyle 2 = b^{2} - 5 b + 6$

# %%
e2.Substrac(2)
# Out:
# $\displaystyle 0 = b^{2} - 5 b + 4$

# %%
e2.factor()
# Out:
# $\displaystyle 0 = \left(b - 4\right) \left(b - 1\right)$

# %%
Q=P.quotient(d,'Q')
# Out:
# $\displaystyle Q =- b x + 2 x^{3} + 5 x^{2} + 5 x + 5$

# %%
S=MyEq(Q.coef_sum(),'S')
# Out:
# $\displaystyle S =17 - b$

# %%
# if b=4... sum coef not >15
S(b=4)
# Out:
# 13

# %%
# if b=1... sum coef is >15 then b=1
S(b=1)
# Out:
# 16

# %%
b=1

# %%
a=e1.solve(a,b=1)
# Out:
# $\displaystyle a =8$

# %% [markdown]
# ![image.png](attachment:73517cb3-98da-4c40-8d77-21db4972fcb9.png)

# %% [markdown]
# ![image.png](attachment:d1bdd9a6-06c8-4bdc-b5a4-82f80a76391d.png)

# %%
# This scrip initializes all variables. 
import sys
sys.path.insert(0, './Libaldo')
from Libaldo import *

# %%
P=MyEq(n*x**5+m*x**4+16*x**3-9*x*x+x+10,'P')
d1=MyEq(x-1,'d1')
d2=MyEq(3*x+2,'d2')
# Out:
# $\displaystyle P =m x^{4} + n x^{5} + 16 x^{3} - 9 x^{2} + x + 10$
# $\displaystyle d1 =x - 1$
# $\displaystyle d2 =3 x + 2$

# %%
e1=P.rem(d1,'e1')
# Out:
# $\displaystyle e1 =m + n + 18$

# %%
n=e1.solve(n)
# Out:
# $\displaystyle n =- m - 18$

# %%
P.upgrade(n)
# Out:
# $\displaystyle P =m x^{4} + x^{5} \left(- m - 18\right) + 16 x^{3} - 9 x^{2} + x + 10$

# %%
e2=P.rem(d2,'e2')
# Out:
# $\displaystyle e2 =\frac{80 m}{243} + \frac{80}{27}$

# %%
m=e2.solve(m)
# Out:
# $\displaystyle m =-9$

# %%
n.upgrade(m)
# Out:
# $\displaystyle n =-9$

# %% [markdown]
# ![image.png](attachment:73517cb3-98da-4c40-8d77-21db4972fcb9.png)

# %% [markdown]
# ![image.png](attachment:a8f12cec-dd33-48ec-8553-e148a8859263.png)

# %%
# This scrip initializes all variables. 
import sys
sys.path.insert(0, './Libaldo')
from Libaldo import *

# %%
P=MyEq(a*x**3+b*x*x+c*x+d,'P')
D1=MyEq(x*x+3,'D1')
D2=MyEq(x*x+6,'D2')
R1=MyEq(2*x+1,'R1')
R2=MyEq(3*x+1,'R2')
# Out:
# $\displaystyle P =a x^{3} + b x^{2} + c x + d$
# $\displaystyle D1 =x^{2} + 3$
# $\displaystyle D2 =x^{2} + 6$
# $\displaystyle R1 =2 x + 1$
# $\displaystyle R2 =3 x + 1$

# %%
A=MyEq(R1-P.rem(D1),'A')
B=MyEq(R2-P.rem(D2),'B')
# Out:
# $\displaystyle A =3 a x + 3 b - c x - d + 2 x + 1$
# $\displaystyle B =6 a x + 6 b - c x - d + 3 x + 1$

# %%
A.factorize(x)
B.factorize(x)
# Out:
# $\displaystyle A =3 b - d + x \left(3 a - c + 2\right) + 1$
# $\displaystyle B =6 b - d + x \left(6 a - c + 3\right) + 1$

# %%
ee=A.coef_list()+B.coef_list()

# %% [markdown]
# ![image.png](attachment:2adeda76-2dae-481d-9ba4-e28ad7733483.png)

# %%
a,b,c,d=solvelist(ee,a,b,c,d)
# Out:
# $\displaystyle a =- \frac{1}{3}$
# $\displaystyle c =1$
# $\displaystyle b =0$
# $\displaystyle d =1$

# %%
P.upgrade(a,b,c,d)
# Out:
# $\displaystyle P =- \frac{x^{3}}{3} + x + 1$

# %%
R=P.rem(D1*D2,'R')
# Out:
# $\displaystyle R =- \frac{x^{3}}{3} + x + 1$

# %% [markdown]
# ![image.png](attachment:73517cb3-98da-4c40-8d77-21db4972fcb9.png)

# %% [markdown]
# ![image.png](attachment:9aeb7307-8a8a-4a01-8f3a-fadecebb4b4d.png)

# %%
# This scrip initializes all variables. 
import sys
sys.path.insert(0, './Libaldo')
from Libaldo import *

# %%
P=MyEq(3*x**4+a*x**3+b*x*x+c*x+d,'P')
D1=MyEq(x*x+1,'D1')
D2=MyEq(x-2,'D2')
D=MyEq(x*x-1,'D')
# Out:
# $\displaystyle P =a x^{3} + b x^{2} + c x + d + 3 x^{4}$
# $\displaystyle D1 =x^{2} + 1$
# $\displaystyle D2 =x - 2$
# $\displaystyle D =x^{2} - 1$

# %%
R1=P.rem(D1,'R1')
# Out:
# $\displaystyle R1 =- a x - b + c x + d + 3$

# %%
R1.factorize(x)
# Out:
# $\displaystyle R1 =- b + d + x \left(- a + c\right) + 3$

# %%
e1=R1.coef_list();e1
# Out:
# [-a + c, -b + d + 3]

# %%
e2=P.coef_sum();e2
# Out:
# a + b + c + d + 3

# %%
e1.append(e2);e1
# Out:
# [-a + c, -b + d + 3, a + b + c + d + 3]

# %%
e3=P.rem(D2);e3
# Out:
# 8⋅a + 4⋅b + 2⋅c + d + 48

# %%
e1.append(e3-50);e1
# Out:
# [-a + c, -b + d + 3, a + b + c + d + 3, 8⋅a + 4⋅b + 2⋅c + d - 2]

# %%
a,b,c,d=solvelist(e1,a,b,c,d)
# Out:
# $\displaystyle a =1$
# $\displaystyle b =-1$
# $\displaystyle c =1$
# $\displaystyle d =-4$

# %%
P.upgrade(a,b,c,d)
# Out:
# $\displaystyle P =3 x^{4} + x^{3} - x^{2} + x - 4$

# %%
R=P.rem(x*x-1,'R')
# Out:
# $\displaystyle R =2 x - 2$

# %% [markdown]
# ![image.png](attachment:73517cb3-98da-4c40-8d77-21db4972fcb9.png)

# %% [markdown]
# ![image.png](attachment:c0c330dd-4401-405b-a100-767213ed7c99.png)

# %%
# This scrip initializes all variables. 
import sys
sys.path.insert(0, './Libaldo')
from Libaldo import *

# %%
#P=MyEq(a*x**3+b*x*x+c*x+d,'P')
D1=MyEq(x*x+5,'D1')
D2=MyEq(x+2,'D2')
R=MyEq(2*x-5,'R')
Q=MyEq(m*x+n,'Q')
# Out:
# $\displaystyle D1 =x^{2} + 5$
# $\displaystyle D2 =x + 2$
# $\displaystyle R =2 x - 5$
# $\displaystyle Q =m x + n$

# %%
A=MQ(P,D1*Q+R)
# Out:
# $\displaystyle P = 2 x + \left(x^{2} + 5\right) \left(m x + n\right) - 5$

# %%
A.expand()
# Out:
# $\displaystyle P = m x^{3} + 5 m x + n x^{2} + 5 n + 2 x - 5$

# %%
A.sortdegree()
# Out:
# $\displaystyle P = m x^{3} + n x^{2} + 5 n + x \left(5 m + 2\right) - 5$

# %%
e1=MyEq(Q.rem(x+2)-4,'e1')
# Out:
# $\displaystyle e1 =- 2 m + n - 4$

# %%
n=e1.solve(n)
# Out:
# $\displaystyle n =2 m + 4$

# %%
A.upgrade(n)
# Out:
# $\displaystyle P = m x^{3} + 10 m + x^{2} \left(2 m + 4\right) + x \left(5 m + 2\right) + 15$

# %%
P=A.solve(P)
# Out:
# $\displaystyle P =m x^{3} + 10 m + x^{2} \left(2 m + 4\right) + x \left(5 m + 2\right) + 15$

# %%
P.rem(x+2)
# Out:
# 27
