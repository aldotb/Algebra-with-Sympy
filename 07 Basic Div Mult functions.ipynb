# %%
# These examples was solved  by Mathematician Professor  ROBERTO CARLOS ALCANTARA CONDORI
# Link
# https://www.youtube.com/watch?v=K9Jms_whis8&list=PLGbSw9USRLuSK4bwHlp_ZCngyyJa58zxB

# %% [markdown]
# ![image.png](attachment:73517cb3-98da-4c40-8d77-21db4972fcb9.png)

# %% [markdown]
# #### Library :  Libaldo.py
# * This library include:
#   * sympy.py The best symbolic math library for me
#   * numpy as np, matplotlib.pyplot as plt IPython.display
#   * libaldo_math2.py this module have some util tools for classic math functions
#   * libaldo_algorith.py some algorith to manage simple math functions
#   * lib_MyEq , this module manage maths Eq
#   * lib_MyEqEq , this module will be MyEq=MyEq
# * Also include the most used variables like   ,x,y,z,alpha,mu..   etc... mayby 150 variables

# %%
# This scrip initializes all variables. 
import sys
sys.path.insert(0, './Libaldo')
from Libaldo import *

# %% [markdown]
# ![image.png](attachment:c15905fe-892f-41fe-a113-d535d29cda49.png)

# %% [markdown]
# ![image.png](attachment:54df9e1e-714e-4371-a5f2-ffb26663218e.png)

# %% [markdown]
# ![image.png](attachment:51dc8fa0-9c85-4e34-adf7-920a92cdbfb1.png)

# %% [markdown]
# #### playing with division parts

# %%
# This scrip initializes all variables. 
import sys
sys.path.insert(0, './Libaldo')
from Libaldo import *

# %%
D=MyEq(3*x*x+2*x+5,'D') # Divident
d=MyEq(3*x-1,'d') # divisor
# Out:
# $\displaystyle D =3 x^{2} + 2 x + 5$
# $\displaystyle d =3 x - 1$

# %%
Q=D.quotient(d,'Q') #  P.quotient(d,'Q') # get quotient between P/d and return in MyEq class called Q
# Out:
# $\displaystyle Q =x + 1$

# %%
R=D.rem(d,'R') # P.rem(d,'R') # get residue between P/d and return in MyEq class called R
# Out:
# $\displaystyle R =6$

# %%
F=MyEq(Q*d+R,'F')
# Out:
# $\displaystyle F =\left(x + 1\right) \left(3 x - 1\right) + 6$

# %%
F.expand()
# Out:
# $\displaystyle F =3 x^{2} + 2 x + 5$

# %%
# comprobation
D-F
# Out:
# 0

# %% [markdown]
# ![image.png](attachment:73517cb3-98da-4c40-8d77-21db4972fcb9.png)

# %% [markdown]
# ![image.png](attachment:30f43645-5714-45d8-8dbc-b1f3e54de013.png)

# %%
# This scrip initializes all variables. 
import sys
sys.path.insert(0, './Libaldo')
from Libaldo import *

# %%
P=MyEq(a*x**4-8*x**2+5*x-1,'P')
D=MyEq(x**2+3*x-1,'D')
Q=MyEq(x**2-3*x+2,'Q')
R=MyEq(x*m+1,'R')
# Out:
# $\displaystyle P =a x^{4} - 8 x^{2} + 5 x - 1$
# $\displaystyle D =x^{2} + 3 x - 1$
# $\displaystyle Q =x^{2} - 3 x + 2$
# $\displaystyle R =m x + 1$

# %%
R1=P.rem(D,'R1')
# Out:
# $\displaystyle R1 =- 33 a x + 10 a + 29 x - 9$

# %%
A=MQ(R,R1)
# Out:
# $\displaystyle m x + 1 = - 33 a x + 10 a + 29 x - 9$

# %%
A.factorize(x,'R')
# Out:
# $\displaystyle m x + 1 = 10 a + x \left(29 - 33 a\right) - 9$

# %%
B=MyEq(10*a-9-1,'B')
# Out:
# $\displaystyle B =10 a - 10$

# %%
a=B.solve(a)
# Out:
# $\displaystyle a =1$

# %%
A.set(a=1)
# Out:
# $\displaystyle m x + 1 = 1 - 4 x$

# %%
m=A.solve(m)
# Out:
# $\displaystyle m =-4$

# %% [markdown]
# ![image.png](attachment:73517cb3-98da-4c40-8d77-21db4972fcb9.png)

# %% [markdown]
# ![image.png](attachment:7f21ec51-3c0b-44be-925a-2ed1e29f7872.png)

# %%
# This scrip initializes all variables. 
import sys
sys.path.insert(0, './Libaldo')
from Libaldo import *

# %%
D=MyEq(x**5+m*x+2,'D')
d=MyEq(x-1,'d')
# Out:
# $\displaystyle D =m x + x^{5} + 2$
# $\displaystyle d =x - 1$

# %%
Q=D.quotient(d,'Q')
# Out:
# $\displaystyle Q =m + x^{4} + x^{3} + x^{2} + x + 1$

# %%
Q.coef_sum(x) # P.coef_sum(x) # return summ of coeficient value when x is main variable
# Out:
# m + 5

# %% [markdown]
# ![image.png](attachment:7cd9c493-2076-469a-a7be-ff50434422c7.png)

# %%
# then m=5

# %%
D.set(m=5)
# Out:
# $\displaystyle D =x^{5} + 5 x + 2$

# %%
R=D.rem(d,'R')
# Out:
# $\displaystyle R =8$

# %%
R.set(m=5)
# Out:
# $\displaystyle R =8$

# %% [markdown]
# ![image.png](attachment:73517cb3-98da-4c40-8d77-21db4972fcb9.png)

# %% [markdown]
# ![image.png](attachment:c02db77f-0849-45c2-b28f-124d594ed19d.png)

# %%
# This scrip initializes all variables. 
import sys
sys.path.insert(0, './Libaldo')
from Libaldo import *

# %%
D=MyEq(3*x**5+m*x**3+k*x**2-x+2,'D')
d=MyEq(x*x+3,'d')
R=MyEq(5*x-10,'R')
# Out:
# $\displaystyle D =k x^{2} + m x^{3} + 3 x^{5} - x + 2$
# $\displaystyle d =x^{2} + 3$
# $\displaystyle R =5 x - 10$

# %%
R2=D.rem(d,'R2')
# Out:
# $\displaystyle R2 =- 3 k - 3 m x + 26 x + 2$

# %%
P=MQ(R,R2)
# Out:
# $\displaystyle 5 x - 10 = - 3 k - 3 m x + 26 x + 2$

# %% [markdown]
# ![image.png](attachment:0320622a-6e24-4742-99ab-55081bad8e26.png)

# %% [markdown]
# #### solve_coef_list()
#     * function is aplied in MQ Class
#     * the number of uknow variable will be < or equal of comprations each to each cefficients...

# %%
m,k=P.solve_coef_list(m,k) # and voilaaaaaa.....
# Out:
# $\displaystyle m =7$
# $\displaystyle k =4$

# %%
m+k
# Out:
# 11

# %% [markdown]
# ![image.png](attachment:73517cb3-98da-4c40-8d77-21db4972fcb9.png)

# %% [markdown]
# ![image.png](attachment:6b2302e4-3485-4f79-8bb8-c74395a32cb9.png)

# %%
# This scrip initializes all variables. 
import sys
sys.path.insert(0, './Libaldo')
from Libaldo import *

# %%
D=MyEq( 3+kpow((x-3),kpow(3,m+3)),'D')
d=MyEq(x*x*x-26+27*x-9*x*x,'d')
# Out:
# $\displaystyle D =\left(x - 3\right)^{3^{m + 3}} + 3$
# $\displaystyle d =x^{3} - 9 x^{2} + 27 x - 26$

# %%
D.set(x,y+3)
d.set(x,y+3)
# Out:
# $\displaystyle D =y^{3^{m + 3}} + 3$
# $\displaystyle d =27 y + \left(y + 3\right)^{3} - 9 \left(y + 3\right)^{2} + 55$

# %%
d.expand()
# Out:
# $\displaystyle d =y^{3} + 1$

# %%
# apply rem teorema
y=-1

# %%
D(y=-1,m=0)
# Out:
# 2

# %% [markdown]
# ![image.png](attachment:73517cb3-98da-4c40-8d77-21db4972fcb9.png)

# %% [markdown]
# ![image.png](attachment:9d5058de-072d-4529-8363-6b9b620d412d.png)

# %%
# This scrip initializes all variables. 
import sys
sys.path.insert(0, './Libaldo')
from Libaldo import *

# %%
D=MyEq(a*x**5+b*x**4+c*x**3-5*x-3,'D')
d=MyEq(2*x*x*x+x*x-x-2,'d')
R=MyEq(7*x*x+8*x-3,'R')
# Out:
# $\displaystyle D =a x^{5} + b x^{4} + c x^{3} - 5 x - 3$
# $\displaystyle d =2 x^{3} + x^{2} - x - 2$
# $\displaystyle R =7 x^{2} + 8 x - 3$

# %%
R2=MyEq(D.rem(d),'R2')
# Out:
# $\displaystyle R2 =\frac{3 a x^{2}}{8} - \frac{a x}{8} + \frac{3 a}{4} + \frac{3 b x^{2}}{4} + \frac{3 b x}{4} - \frac{b}{2} - \frac{c x^{2}}{2} + \frac{c x}{2} + c - 5 x - 3$

# %%
R2.sortdegree(x) # P.sortdegree(x) if P=3*x*x+a*x*x+b*x+3*x+7, return (3+a)*x*x+(b+3)*x+7
# Out:
# $\displaystyle R2 =\frac{3 a}{4} - \frac{b}{2} + c + x^{2} \left(\frac{3 a}{8} + \frac{3 b}{4} - \frac{c}{2}\right) + x \left(- \frac{a}{8} + \frac{3 b}{4} + \frac{c}{2} - 5\right) - 3$

# %% [markdown]
# ![image.png](attachment:e4cb30ca-e176-48df-8ba1-3e8b1cf37f36.png)

# %% [markdown]
# ![image.png](attachment:67839272-37ff-4225-8cee-bf16f9ad904a.png)

# %%
P=MQ(R,R2)
# Out:
# $\displaystyle 7 x^{2} + 8 x - 3 = \frac{3 a}{4} - \frac{b}{2} + c + x^{2} \left(\frac{3 a}{8} + \frac{3 b}{4} - \frac{c}{2}\right) + x \left(- \frac{a}{8} + \frac{3 b}{4} + \frac{c}{2} - 5\right) - 3$

# %%
a,b,c=P.solve_coef_list(a,b,c) # and voilaaaaaa.....
# Out:
# $\displaystyle a =\frac{1}{2}$
# $\displaystyle b =\frac{53}{4}$
# $\displaystyle c =\frac{25}{4}$

# %%
a+b+c
# Out:
# 20

# %% [markdown]
# ![image.png](attachment:73517cb3-98da-4c40-8d77-21db4972fcb9.png)

# %% [markdown]
# ![image.png](attachment:bcb9b43d-7761-4924-9397-a6b0fe29fc9c.png)

# %%
# This scrip initializes all variables. 
import sys
sys.path.insert(0, './Libaldo')
from Libaldo import *

# %%
D=MyEq((x-1)**7-(x-2)**7-1,'D')
d=MyEq(x*x-3*x+2,'d')
# Out:
# $\displaystyle D =- \left(x - 2\right)^{7} + \left(x - 1\right)^{7} - 1$
# $\displaystyle d =x^{2} - 3 x + 2$

# %%
R=D.rem(d,'R')
# Out:
# $\displaystyle R =0$

# %% [markdown]
# ![image.png](attachment:73517cb3-98da-4c40-8d77-21db4972fcb9.png)

# %% [markdown]
# ![image.png](attachment:26b2fad0-f3dd-4346-b119-add212e5030a.png)

# %%
# This scrip initializes all variables. 
import sys
sys.path.insert(0, './Libaldo')
from Libaldo import *

# %%
D=MyEq(a*x**4+b*x**3+c*x*x+x+3,'D')
d=MyEq(3*x*x-3*x+1,'d')
R=MyEq(2*x+1,'R')
# Out:
# $\displaystyle D =a x^{4} + b x^{3} + c x^{2} + x + 3$
# $\displaystyle d =3 x^{2} - 3 x + 1$
# $\displaystyle R =2 x + 1$

# %%
Q=D.quotient(d,'Q')
# Out:
# $\displaystyle Q =\frac{a x^{2}}{3} + \frac{a x}{3} + \frac{2 a}{9} + \frac{b x}{3} + \frac{b}{3} + \frac{c}{3}$

# %% [markdown]
# ![image.png](attachment:dff45343-c539-4605-9092-f5c0dd557e85.png)

# %%
mm=Q.coef_list();mm
# Out:
# ⎡a  a   b  2⋅a   b   c⎤
# ⎢─, ─ + ─, ─── + ─ + ─⎥
# ⎣3  3   3   9    3   3⎦

# %% [markdown]
# ![image.png](attachment:c2470c88-da75-40fb-b543-eb07ea7d849a.png)

# %%
K=MyEq(mm[0]*mm[1]*mm[2]-8,'K')
# Out:
# $\displaystyle K =\frac{a \left(\frac{a}{3} + \frac{b}{3}\right) \left(\frac{2 a}{9} + \frac{b}{3} + \frac{c}{3}\right)}{3} - 8$

# %%
A=MQ(D.rem(d),R)
# Out:
# $\displaystyle \frac{a x}{3} - \frac{2 a}{9} + \frac{2 b x}{3} - \frac{b}{3} + c x - \frac{c}{3} + x + 3 = 2 x + 1$

# %%
a,b=A.solve_coef_list(a,b) # only two variables when two there is two eq equality
# Out:
# $\displaystyle a =3 c + 27$
# $\displaystyle b =- 3 c - 12$

# %%
K.upgrade(a,b) # upgrade() is used to up finding values
# Out:
# $\displaystyle K =10 c + 82$

# %%
c=K.solve(c)
# Out:
# $\displaystyle c =- \frac{41}{5}$

# %%
a.upgrade(c)
b.upgrade(c)
# Out:
# $\displaystyle a =\frac{12}{5}$
# $\displaystyle b =\frac{63}{5}$

# %% [markdown]
# ![image.png](attachment:73517cb3-98da-4c40-8d77-21db4972fcb9.png)

# %% [markdown]
# ![image.png](attachment:6eaa8ca8-d5e0-4418-89f4-4e9cd5a954f9.png)

# %%
# This scrip initializes all variables. 
import sys
sys.path.insert(0, './Libaldo')
from Libaldo import *

# %%
D=MyEq(a*x**3+b*x**2+c*x+d,'D')
d1=MyEq(2*x-1,'d1')
Q1=MyEq(x*x+2*x-3,'Q1')
d2=MyEq(2*x+1,'d2')
R2=MyEq(1,'R2')
# Out:
# $\displaystyle D =a x^{3} + b x^{2} + c x + d$
# $\displaystyle d1 =2 x - 1$
# $\displaystyle Q1 =x^{2} + 2 x - 3$
# $\displaystyle d2 =2 x + 1$
# $\displaystyle R2 =1$

# %%
A=MQ(D.quotient(d1),Q1)
B=MQ(D.rem(d2),R2)
# Out:
# $\displaystyle \frac{a x^{2}}{2} + \frac{a x}{4} + \frac{a}{8} + \frac{b x}{2} + \frac{b}{4} + \frac{c}{2} = x^{2} + 2 x - 3$
# $\displaystyle - \frac{a}{8} + \frac{b}{4} - \frac{c}{2} + d = 1$

# %%
a,b,c=A.solve_coef_list(a,b,c)
# Out:
# $\displaystyle a =2$
# $\displaystyle b =3$
# $\displaystyle c =-8$

# %%
d=B.solve(d)
# Out:
# $\displaystyle d =\frac{a}{8} - \frac{b}{4} + \frac{c}{2} + 1$

# %%
d.upgrade(a,b,c)
# Out:
# $\displaystyle d =- \frac{7}{2}$

# %%
D.upgrade(a,b,c,d)
# Out:
# $\displaystyle D =2 x^{3} + 3 x^{2} - 8 x - \frac{7}{2}$

# %%
D.rem(2*x-1)
# Out:
# -13/2

# %% [markdown]
# ![image.png](attachment:73517cb3-98da-4c40-8d77-21db4972fcb9.png)

# %% [markdown]
# ![image.png](attachment:4ec04ef8-5b37-4270-aded-6aff2fd3aa60.png)

# %%
# This scrip initializes all variables. 
import sys
sys.path.insert(0, './Libaldo')
from Libaldo import *

# %%
D=MyEq(a*x**4+b*x**3+16*x-25,'D')
d=MyEq(2*x*x-x+4,'d')

R=MyEq(3*x-5,'R')
# Out:
# $\displaystyle D =a x^{4} + b x^{3} + 16 x - 25$
# $\displaystyle d =2 x^{2} - x + 4$
# $\displaystyle R =3 x - 5$

# %%
A=MQ(D.rem(d),R)
# Out:
# $\displaystyle - \frac{15 a x}{8} + \frac{7 a}{2} - \frac{7 b x}{4} - b + 16 x - 25 = 3 x - 5$

# %%
a,b=A.solve_coef_list(a,b)
# Out:
# $\displaystyle a =6$
# $\displaystyle b =1$

# %%
a+b
# Out:
# 7

# %% [markdown]
# ![image.png](attachment:73517cb3-98da-4c40-8d77-21db4972fcb9.png)

# %% [markdown]
# ![image.png](attachment:1cdad120-39de-4273-8423-9505a7d171f0.png)

# %%
# This scrip initializes all variables. 
import sys
sys.path.insert(0, './Libaldo')
from Libaldo import *

# %%
D=MyEq(2*x**5+x**4+a*x*x+b*x+c,'D')
d=MyEq(x**4-1,'d')
P=MyEq((a+b)/(a-b),'P')
# Out:
# $\displaystyle D =a x^{2} + b x + c + 2 x^{5} + x^{4}$
# $\displaystyle d =x^{4} - 1$
# $\displaystyle P =\frac{a + b}{a - b}$

# %%
Q=D.quotient(d,'Q')
# Out:
# $\displaystyle Q =2 x + 1$

# %%
A=MQ(D,expand(Q*d))
# Out:
# $\displaystyle a x^{2} + b x + c + 2 x^{5} + x^{4} = 2 x^{5} + x^{4} - 2 x - 1$

# %%
A.simplify()
# Out:
# $\displaystyle a x^{2} + b x + c = - 2 x - 1$

# %%
A.set(a=0)
# Out:
# $\displaystyle b x + c = - 2 x - 1$

# %%
b,c=A.solve_coef_list(b,c)
# Out:
# $\displaystyle b =-2$
# $\displaystyle c =-1$

# %%
a=0
P.set(a=0,b=-2)
# Out:
# $\displaystyle P =-1$

# %% [markdown]
# ![image.png](attachment:73517cb3-98da-4c40-8d77-21db4972fcb9.png)

# %% [markdown]
# ![image.png](attachment:a0b35afa-6b24-4156-9e49-1750b9454963.png)

# %%
# This scrip initializes all variables. 
import sys
sys.path.insert(0, './Libaldo')
from Libaldo import *

# %%
D=MyEq(a*x**4+b*x**3+c*x*x+d*x+m,'D')
d1=MyEq(x**2+x+1,'d1')
d2=MyEq(x**2-x+1,'d2')
R1=MyEq(x+1,'R1')
R2=MyEq(x-1,'R2')
d3=MyEq(x**4+x*x+1,'d3')
# Out:
# $\displaystyle D =a x^{4} + b x^{3} + c x^{2} + d x + m$
# $\displaystyle d1 =x^{2} + x + 1$
# $\displaystyle d2 =x^{2} - x + 1$
# $\displaystyle R1 =x + 1$
# $\displaystyle R2 =x - 1$
# $\displaystyle d3 =x^{4} + x^{2} + 1$

# %%
A=MQ(D.rem(d1),R1)
B=MQ(D.rem(d2),R2)
# Out:
# $\displaystyle a x + b - c x - c + d x + m = x + 1$
# $\displaystyle - a x - b + c x - c + d x + m = x - 1$

# %%
#  finding a and b in A with solve_coef_list
a,b=A.solve_coef_list(a,b)
# Out:
# $\displaystyle a =c - d + 1$
# $\displaystyle b =c - m + 1$

# %%
#  replace this value in B
B.upgrade(a,b)
# Out:
# $\displaystyle c x - 2 c + d x + 2 m - x \left(c - d + 1\right) - 1 = x - 1$

# %%
#  finding c and d in B with solve_coef_list
c,d=B.solve_coef_list(c,d)
# Out:
# $\displaystyle c =1$
# $\displaystyle d =m$

# %%
B.upgrade(c,d)
# Out:
# $\displaystyle m x + 2 m - x \left(2 - m\right) + x - 3 = x - 1$

# %%
B.expand()
# Out:
# $\displaystyle 2 m x + 2 m - x - 3 = x - 1$

# %%
# solve m in B if x=0
m=B.solve(m,x=0)
# Out:
# $\displaystyle m =1$

# %%
Upgrade(a,b,d,c,m)
# Out:
# $\displaystyle a =1$
# $\displaystyle b =1$
# $\displaystyle d =1$
# $\displaystyle c =1$
# $\displaystyle m =1$

# %%
D.upgrade(a,b,c,d,m)
# Out:
# $\displaystyle D =x^{4} + x^{3} + x^{2} + x + 1$

# %%
D.rem(d3)
# Out:
#  3
# x  + x
