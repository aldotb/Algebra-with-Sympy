# %% [markdown]
# ![image.png](attachment:73517cb3-98da-4c40-8d77-21db4972fcb9.png)

# %% [markdown]
# #### Library :  Libaldo.py
# * This library include:
#   * sympy.py The best symbolic math library for me
#   * numpy as np, matplotlib.pyplot as plt IPython.display
#   * libaldo_math2.py this module have some util tools for classic math functions
#   * libaldo_algorith.py some algorith to manage simple math functions
#   * lib_MyEq , this module manage maths Eq
#   * lib_MyEqEq , this module will be MyEq=MyEq
# * Also include the most used variables like   ,x,y,z,alpha,mu..   etc... mayby 150 variables

# %% [markdown]
# ![image.png](attachment:54df9e1e-714e-4371-a5f2-ffb26663218e.png)

# %% [markdown]
# ![image.png](attachment:73517cb3-98da-4c40-8d77-21db4972fcb9.png)

# %% [markdown]
# ![image.png](attachment:bb9ef712-ef51-4c53-8940-d517390b6099.png)

# %%
# This scrip initializes all variables. 
import sys
sys.path.insert(0, './Libaldo')
from Libaldo import *

# %%
Lshow('if sqrt of P(x) is exact ..find (a-b)/a   ...')
P=MyEq(a*x**6+b*x**5+8*x**4+4*x**3+16*x*x+16*x+4,'P')
# Out:
# $\displaystyle if\;sqrt\;of\;P(x)\;is\;exact\;..find\;(a-b)/a\;...\;$
# $\displaystyle P =a x^{6} + b x^{5} + 8 x^{4} + 4 x^{3} + 16 x^{2} + 16 x + 4$

# %%
Lshow('root will have the following form   ...')
R=MyEq(sqrs(a)*x**3+m*x**2+n*x+2,'R')
# Out:
# $\displaystyle root\;will\;have\;the\;following\;form\;...\;$
# $\displaystyle R =\sqrt{a} x^{3} + m x^{2} + n x + 2$

# %%
# then 
Q=MQ(P,R*R)
# Out:
# $\displaystyle a x^{6} + b x^{5} + 8 x^{4} + 4 x^{3} + 16 x^{2} + 16 x + 4 = \left(\sqrt{a} x^{3} + m x^{2} + n x + 2\right)^{2}$

# %%
Q.expand()
# Out:
# $\displaystyle a x^{6} + b x^{5} + 8 x^{4} + 4 x^{3} + 16 x^{2} + 16 x + 4 = 2 \sqrt{a} m x^{5} + 2 \sqrt{a} n x^{4} + 4 \sqrt{a} x^{3} + a x^{6} + m^{2} x^{4} + 2 m n x^{3} + 4 m x^{2} + n^{2} x^{2} + 4 n x + 4$

# %%
# simplify sidem terms
Q.simplify()
# Out:
# $\displaystyle b x^{5} + 8 x^{4} + 4 x^{3} + 16 x^{2} + 16 x = 2 \sqrt{a} m x^{5} + 2 \sqrt{a} n x^{4} + 4 \sqrt{a} x^{3} + m^{2} x^{4} + 2 m n x^{3} + 4 m x^{2} + n^{2} x^{2} + 4 n x$

# %%
Q.sortdegree()
# Out:
# $\displaystyle b x^{5} + 8 x^{4} + 4 x^{3} + 16 x^{2} + 16 x = 2 \sqrt{a} m x^{5} + 4 n x + x^{4} \left(2 \sqrt{a} n + m^{2}\right) + x^{3} \left(4 \sqrt{a} + 2 m n\right) + x^{2} \left(4 m + n^{2}\right)$

# %% [markdown]
# ![image.png](attachment:783e4b9c-e96a-4e38-89fe-9f627d1eecde.png)

# %%
# by comparation
b=solved(b,b-2*m*sqrs(a))
# Out:
# $\displaystyle b =2 \sqrt{a} m$

# %%
Q.s() # show Q
# Out:
# $\displaystyle b x^{5} + 8 x^{4} + 4 x^{3} + 16 x^{2} + 16 x = 2 \sqrt{a} m x^{5} + 4 n x + x^{4} \left(2 \sqrt{a} n + m^{2}\right) + x^{3} \left(4 \sqrt{a} + 2 m n\right) + x^{2} \left(4 m + n^{2}\right)$

# %%
# by comparation
n=solved(n,16-4*n)
# Out:
# $\displaystyle n =4$

# %%
# updated n in Q
Q.upgrade(n)
# Out:
# $\displaystyle b x^{5} + 8 x^{4} + 4 x^{3} + 16 x^{2} + 16 x = 2 \sqrt{a} m x^{5} + x^{4} \left(8 \sqrt{a} + m^{2}\right) + x^{3} \left(4 \sqrt{a} + 8 m\right) + x^{2} \left(4 m + 16\right) + 16 x$

# %%
# by comparation
m=solved(m,16-(4*m+16))
# Out:
# $\displaystyle m =0$

# %%
# updated n in Q
Q.upgrade(m)
# Out:
# $\displaystyle b x^{5} + 8 x^{4} + 4 x^{3} + 16 x^{2} + 16 x = 8 \sqrt{a} x^{4} + 4 \sqrt{a} x^{3} + 16 x^{2} + 16 x$

# %%
# by comparation in grade 3
a=solved(a,4-4*sqrs(a))
# Out:
# $\displaystyle a =1$

# %%
# updated a in b
b.upgrade(m)
# Out:
# $\displaystyle b =0$

# %%
(a-b)/a
# Out:
# 1

# %% [markdown]
# ![image.png](attachment:73517cb3-98da-4c40-8d77-21db4972fcb9.png)

# %% [markdown]
# ![image.png](attachment:a77457d6-68e1-462f-be02-cc3277de15d9.png)

# %% [markdown]
# Descompone this :
# ![image.png](attachment:b6d88172-34b2-448b-85a0-93730f556dba.png)
# Like simple Radication if :
# ![image.png](attachment:7e3f6ff9-4fe9-4c61-92a7-82537961a11c.png)

# %%
# This scrip initializes all variables. 
import sys
sys.path.insert(0, './Libaldo')
from Libaldo import *

# %%
Q=MQ(sqrs(A+sqrs(B)),sqrs(m)+sqrs(n))
# Out:
# $\displaystyle \sqrt{A + \sqrt{B}} = \sqrt{m} + \sqrt{n}$

# %%
Q.Pow(2)
# Out:
# $\displaystyle A + \sqrt{B} = \left(\sqrt{m} + \sqrt{n}\right)^{2}$

# %%
Q.expand()
# Out:
# $\displaystyle A + \sqrt{B} = 2 \sqrt{m} \sqrt{n} + m + n$

# %%
Q.factorexp()
# Out:
# $\displaystyle A + \sqrt{B} = 2 \sqrt{m} \sqrt{n} + m + n$

# %%
# then
A=MyEq(m+n,'A')
B=MyEq(4*m*n,'B')
# Out:
# $\displaystyle A =m + n$
# $\displaystyle B =4 m n$

# %%
P=MQ(4*A+B,4*x*x+8*x-16)
# Out:
# $\displaystyle 4 m n + 4 m + 4 n = 4 x^{2} + 8 x - 16$

# %%
P.Div(4)
# Out:
# $\displaystyle m n + m + n = x^{2} + 2 x - 4$

# %%
P.Substrac(2*x)
# Out:
# $\displaystyle m n + m + n - 2 x = x^{2} - 4$

# %%
P.factor()
# Out:
# $\displaystyle m n + m + n - 2 x = \left(x - 2\right) \left(x + 2\right)$

# %%
P.Add(2*x)
# Out:
# $\displaystyle m n + m + n = 2 x + \left(x - 2\right) \left(x + 2\right)$

# %% [markdown]
# ![image.png](attachment:c661d4bb-6b12-4dda-8bc4-2e240f974b8e.png)

# %% [markdown]
# ![image.png](attachment:a671c627-22c7-4a45-b2af-ac327cabcc6e.png)

# %% [markdown]
# ![image.png](attachment:73517cb3-98da-4c40-8d77-21db4972fcb9.png)

# %% [markdown]
# Find A and B if :
# ![image.png](attachment:7a926055-b5ac-46af-a936-47a18377ab4e.png)

# %%
# This scrip initializes all variables. 
import sys
sys.path.insert(0, './Libaldo')
from Libaldo import *

# %%
P=MyEq(sqrs(8*x*x+24*x+9-4*(2*x+3)*sqrs(x*x+3*x) ,4),'P')
Q=MyEq(sqrs(x+A)+B*sqrs(x),'Q')
# Out:
# $\displaystyle P =\sqrt[4]{8 x^{2} + 24 x - \left(8 x + 12\right) \sqrt{x^{2} + 3 x} + 9}$
# $\displaystyle Q =B \sqrt{x} + \sqrt{A + x}$

# %% [markdown]
# try to Find ![image.png](attachment:98ee898a-a2a4-4f23-824e-efe81299cc10.png) in...
# ![image.png](attachment:0e5a258e-add0-4b9f-88a6-f50affb876fb.png)

# %%
# trying to build a dynamic expressio

# %% [markdown]
# Find A and B if :
# ![image.png](attachment:7a926055-b5ac-46af-a936-47a18377ab4e.png)

# %%
e1=MyEq(x+3,'e1');e2=MyEq(2*x+3,'e2');e3=MyEq(8*x*x+24*x+9,'e3')
# Out:
# $\displaystyle e1 =x + 3$
# $\displaystyle e2 =2 x + 3$
# $\displaystyle e3 =8 x^{2} + 24 x + 9$

# %% [markdown]
# ![image.png](attachment:e1e64c48-110c-4140-ab37-dcfbb1621913.png)

# %%
e3.transformada('A+(2*x+3)**2','A','es')
# Out:
# $\displaystyle e3 =4 x \left(x + 3\right) + \left(2 x + 3\right)^{2}$

# %%
4*x*e1*kpow(e2,2)
# Out:
#                      2
# 4⋅x⋅(x + 3)⋅(2⋅x + 3)

# %% [markdown]
# ![image.png](attachment:a76048ec-0108-4ebe-9459-8b89560336c7.png)

# %%
e4=MyEq(2*sqrs(4*x*e1*kpow(e2,2),2),'e4')
# Out:
# $\displaystyle e4 =4 \sqrt{x \left(x + 3\right) \left(2 x + 3\right)^{2}}$

# %%
# then..........
P=MyEq(sqrs(e4+e3,4),'P')
# Out:
# $\displaystyle P =\sqrt[4]{4 x \left(x + 3\right) + 4 \sqrt{x \left(x + 3\right) \left(2 x + 3\right)^{2}} + \left(2 x + 3\right)^{2}}$

# %% [markdown]
# ![image.png](attachment:98ee898a-a2a4-4f23-824e-efe81299cc10.png)

# %%
a=MyEq(sqrs(4*x*(x+3)),'a')
b=MyEq(sqrs((2*x+3)**2),'b')
# Out:
# $\displaystyle a =2 \sqrt{x \left(x + 3\right)}$
# $\displaystyle b =\sqrt{\left(2 x + 3\right)^{2}}$

# %%
b.killsqrtpow()
# Out:
# $\displaystyle b =2 x + 3$

# %%
a+b
# Out:
#           ___________
# 2⋅x + 2⋅╲╱ x⋅(x + 3)  + 3

# %%
P2=MyEq(rpow(a+b),'P2')
# Out:
# $\displaystyle P2 =\sqrt{2 x + 2 \sqrt{x \left(x + 3\right)} + 3}$

# %% [markdown]
# ![image.png](attachment:98ee898a-a2a4-4f23-824e-efe81299cc10.png)

# %%
X=MyEq(x,'X')
Y=MyEq(x+3,'Y')
# Out:
# $\displaystyle X =x$
# $\displaystyle Y =x + 3$

# %%
Q2=MQ(sqrs(X)+sqrs(Y),Q)
# Out:
# $\displaystyle \sqrt{x} + \sqrt{x + 3} = B \sqrt{x} + \sqrt{A + x}$

# %%
# then...  A=3,B=1

# %% [markdown]
# ![image.png](attachment:73517cb3-98da-4c40-8d77-21db4972fcb9.png)

# %% [markdown]
# ![image.png](attachment:3f39920f-0580-4eb1-9ba2-a27aef98baec.png)

# %%
# This scrip initializes all variables. 
import sys
sys.path.insert(0, './Libaldo')
from Libaldo import *

# %% [markdown]
# ![image.png](attachment:c2300ab4-99ef-4896-812d-34baf9813c34.png)

# %%
P1=MQ(A,sqrs(2+sqrs(3)))
# Out:
# $\displaystyle A = \sqrt{\sqrt{3} + 2}$

# %%
P1.Pow(2)
# Out:
# $\displaystyle A^{2} = \sqrt{3} + 2$

# %%
P1.Mul(2)
# Out:
# $\displaystyle 2 A^{2} = 2 \sqrt{3} + 4$

# %% [markdown]
# ![image.png](attachment:98ee898a-a2a4-4f23-824e-efe81299cc10.png)

# %%
P1.Rpow(2)
# Out:
# $\displaystyle \sqrt{2} A = \sqrt{2 \sqrt{3} + 4}$

# %%
P1.setR(sqrs(3)+1)
# Out:
# $\displaystyle \sqrt{2} A = 1 + \sqrt{3}$

# %%
A=P1.solve(A)
# Out:
# $\displaystyle A =\frac{\sqrt{2}}{2} + \frac{\sqrt{6}}{2}$

# %% [markdown]
# ![image.png](attachment:09a93a88-7116-47cf-b7d0-9e2a8cd46cad.png)

# %%
B=MyEq(sqrs(2)/2-sqrs(6)/2,'B')
# Out:
# $\displaystyle B =- \frac{\sqrt{6}}{2} + \frac{\sqrt{2}}{2}$

# %% [markdown]
# ![image.png](attachment:6808bb70-3804-4cdf-895b-5a8e53ae0d94.png)
